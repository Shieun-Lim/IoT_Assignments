# %%
import requests

r=requests.get('https://www.kma.go.kr/plus/rss.jsp')
print(r.text)
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# 	<meta http-equiv="X-UA-Compatible" content="IE=Edge" />
# 	<title>기상청 RSS</title>
# 	<meta charset="utf-8" />
# 	<meta name="title" content="기상청 기상 플러스" />
# 	<meta name="author" content="기상청" />
# 	<meta name="keywords" content="날씨, 기상청, 기상 플러스" />
# 	<meta name="description" content="기상청 날씨누리 기상플러스입니다." />
#
#
# 		<link href="/plus/resources/css/slick.css?ver=20191010" rel="stylesheet" type="text/css">
# 		<link href="/plus/resources/css/basic.css?ver=20191010" rel="stylesheet" type="text/css">
# 		<link href="/plus/resources/css/common-layout.css?ver=20191010" rel="stylesheet" type="text/css">
# 		<link href="/plus/resources/css/plus.css?ver=20191010" rel="stylesheet" type="text/css">
# 		<link href="/plus/resources/css/custom.css?ver=20191010" rel="stylesheet" type="text/css">
#
# 		<script src="/plus/resources/js/moment-with-locales.js"></script>
# 		<script src="/plus/resources/js/jquery-1.7.2.min.js"></script>
# ...
